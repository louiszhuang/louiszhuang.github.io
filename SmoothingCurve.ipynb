// %%
:dep plotters = { version = "^0.2.15", default_features = false, features = ["evcxr", "line_series"] }
:dep qlab = { path = "c:/dev/qlab" }
:dep chrono
:dep time

// %%
use plotters::prelude::*;
use qlab::{act365, DiscountCurve, InterpolationType, ZeroCurve, NaiveGilt, Currency, Funding, fit_curve_by_critical_dates};
use chrono::NaiveDate;
use time::Duration;

// %%
    
    let anchor:NaiveDate = NaiveDate::from_ymd(2020, 8, 11);
    let cutoff:NaiveDate = anchor;
    let tr65:NaiveGilt<NaiveDate> = NaiveGilt::new(0.025, NaiveDate::from_ymd(2065, 7, 22), cutoff)?;
    let tr68:NaiveGilt<NaiveDate> = NaiveGilt::new(0.035, NaiveDate::from_ymd(2068, 7, 22), cutoff)?;
    let tr71:NaiveGilt<NaiveDate> = NaiveGilt::new(0.01625, NaiveDate::from_ymd(2071, 10, 22), cutoff)?;
    let curves:Vec<((Currency,Funding),Box<dyn DiscountCurve<NaiveDate>>)> = fit_curve_by_critical_dates(
        cutoff,
        &[(
            (Currency::GBP, Funding::HMTreasury),
            vec![(1.7443, &tr65), (2.2156, &tr68), (1.4986, &tr71)],
        )],
        &[InterpolationType::Linear],
        &[1e-3],
        &[],
    )?;
// Out:
// 9973 - 0.0888545152439283
// 19946 - 0.001798888101665778
// 29919 - -0.000001687855787583154
// Calibration report: MinimizationReport { termination: Converged { ftol: true, xtol: false }, number_of_evaluations: 7, objective_function: 0.000000000000000009487211896244538 } Matrix { data: VecStorage { data: [0.008074523036341335, 0.008074434345553164, 0.008074273057173516, 0.008074039355860669, 0.008073733460965186, 0.00807335604324334, 0.008072909292955639, 0.008072367340731215, 0.008071740799741987, 0.008071051344177137, 0.00807027567027265, 0.008069412967242735, 0.008068461976713346, 0.008067421539581227, 0.008066290205842723, 0.008065066661559614, 0.008063740991353756, 0.008062325325597074, 0.00806083776389453, 0.008059234086349855, 0.008057517975009905, 0.008055705881554872, 0.00805382404321667, 0.008051815304772737, 0.008049683600570633, 0.008047449945449337, 0.00804514926701205, 0.0080427106909338, 0.008040138390572459, 0.008037414061629881, 0.008034661555611791, 0.008031789725229787, 0.008028797259823528, 0.00802568289964106, 0.00802244528291924, 0.008019083102046434, 0.008015594959031496, 0.008011947643305518, 0.008008244831317941, 0.008004369739388579, 0.008000327222188982, 0.007996159122468148, 0.007991940562067448, 0.007987537852133554, 0.007982956064599483, 0.00797824290131693, 0.007973440726645553, 0.007968495831454628, 0.007963359611897342, 0.00795798838599079, 0.007952792591810065, 0.007947267598665375, 0.00794143248655395, 0.007935634559552781, 0.00792968266393066, 0.007923575490888776, 0.007917311678905234, 0.007910889902504561, 0.00790430878693336, 0.007897566993375502, 0.007890663136732513, 0.007883527910984605, 0.007876306290616747, 0.007868918109316543, 0.00786128888199777, 0.007853499406586204, 0.007845700821824885, 0.007837641895418962, 0.007829328971806864, 0.007820850265781025, 0.007812371445389578, 0.007803618895443892, 0.0077945991651173895, 0.007785229077315484, 0.007776250867233, 0.007766778589331681, 0.007756834932978704, 0.007747025122286368, 0.0077370263028926755, 0.007726837169480184, 0.00771645638385168, 0.007705777616621831, 0.00769512854760009, 0.007684164107073927, 0.007672891454887098, 0.00766143092199497, 0.007650011222970536, 0.0076382618901535936, 0.007626190284157013, 0.007613925404448445, 0.007601713009065374, 0.007589156496502972, 0.007576263427283847, 0.007563171714032598, 0.007550012238473032, 0.007536639875480341, 0.007522641914046407, 0.0075088788332251365, 0.007494897949513398, 0.007480697990035791, 0.007466277656792565, 0.007451635672170291, 0.00743677073432492, 0.007421681561644019, 0.007406366849111799, 0.007390667416763337, 0.007375071877273335, 0.007359072016169316, 0.0073426761843894545, 0.007326060306094175, 0.007309392731553447, 0.007292489924157019, 0.007275175624830811, 0.007257635728024301, 0.007240228081857526, 0.007222384649494004, 0.00720411417032449, 0.007185237594899873, 0.007167291215390775, 0.007148481821479355, 0.007128838396316926, 0.007109577594673455, 0.007090066015859369, 0.007070302408310772, 0.007050285501441798, 0.007030014041075908, 0.007009486754528817, 0.006988702385388035, 0.006967442907405741, 0.006945937029223344, 0.006924627112132672, 0.006902816170269563, 0.0068805137099543084, 0.006857959758692661, 0.006835619037184966, 0.006812760476184513, 0.0067893937717655945, 0.006765770501316405, 0.006742378208515026, 0.006718451047659498, 0.006693998903702974, 0.006668777976700116, 0.006644089664335145, 0.006619122121410569, 0.006593874106487263, 0.006568344391877175, 0.006542531734117739, 0.006516434903395416, 0.00649005265445833, 0.006463106600571863, 0.006436447160980383, 0.006409200415482638, 0.006381376808639018, 0.006353276289930237, 0.006325482066009895, 0.006297082662194253, 0.006268088708502362, 0.006238812856586965, 0.0062095586009248156, 0.006180004479887504, 0.006149837821756949, 0.006118754688549916, 0.0060893158341715665, 0.00605856220265775, 0.006026528777788359, 0.005995215634774426, 0.005963592987818554, 0.005931659625791394, 0.005899414323878821, 0.005866855868871712, 0.005833983034095431, 0.005800794604392345, 0.005767289351345632 ...

// %%
let mut dfs = vec![1f64; 365*60];
{
    let mut ds: Vec<NaiveDate> = vec![];
    for i in 0..dfs.len() {
        let d = anchor + Duration::days(i as i64);
        ds.push(d);
    }
    let ds: Vec<NaiveDate> = ds;
    let curve: &dyn DiscountCurve<NaiveDate> = &curves[0].1;
    curve.dfs(&ds, &mut dfs)?
}
// Out:
// ()

// %%
let fig = evcxr_figure((800, 600), |root| {
    let mut fs = vec![0.;dfs.len()-1];
    for i in 1..dfs.len() {
        fs[i-1] = (dfs[i-1]/dfs[i]-1.)*365.
    }
    root.fill(&WHITE)?;
    let mut chart = ChartBuilder::on(&root)
        .caption("Flat forward curve!", ("Arial", 20).into_font())
        .x_label_area_size(40)
        .y_label_area_size(40)
        .build_ranged(0..fs.len(), -0.01f64..0.01f64)?;
    chart.configure_mesh()
        .y_labels(10)
        .line_style_2(&TRANSPARENT)
        .x_desc("Date")
        .y_desc("Rate")
        .disable_x_mesh()
        .draw()?;
    // Then we can draw a series on it!
    chart.draw_series(LineSeries::new(fs.iter().enumerate().map(|(i, &df)| (i, df)), &RED))?
    .legend(|(x,y)| PathElement::new(vec![(x,y), (x + 20,y)], &RED))
    .label("daily rate");
    chart
        .configure_series_labels()
        .background_style(&WHITE.mix(0.8))
        .border_style(&BLACK)
        .draw()?;
    Ok(())
}).style("");
fig
// Out:
// <div style=""><svg width="800" height="600" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg">
// <rect x="0" y="0" width="799" height="599" opacity="1" fill="#FFFFFF" stroke="none"/>
// <text x="400" y="5" dy="0.76em" text-anchor="middle" font-family="Arial" font-size="16.129032258064516" opacity="1" fill="#000000">
// Flat forward curve!
// </text>
// <text x="0" y="293" dy="0.76em" text-anchor="middle" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000" transform="rotate(270, 0, 293)">
// Rate
// </text>
// <text x="420" y="600" dy="-0.5ex" text-anchor="middle" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// Date
// </text>
// <line opacity="0.2" stroke="#000000" stroke-width="1" x1="40" y1="505" x2="800" y2="505"/>
// <line opacity="0.2" stroke="#000000" stroke-width="1" x1="40" y1="452" x2="800" y2="452"/>
// <line opacity="0.2" stroke="#000000" stroke-width="1" x1="40" y1="398" x2="800" y2="398"/>
// <line opacity="0.2" stroke="#000000" stroke-width="1" x1="40" y1="345" x2="800" y2="345"/>
// <line opacity="0.2" stroke="#000000" stroke-width="1" x1="40" y1="292" x2="800" y2="292"/>
// <line opacity="0.2" stroke="#000000" stroke-width="1" x1="40" y1="238" x2="800" y2="238"/>
// <line opacity="0.2" stroke="#000000" stroke-width="1" x1="40" y1="185" x2="800" y2="185"/>
// <line opacity="0.2" stroke="#000000" stroke-width="1" x1="40" y1="131" x2="800" y2="131"/>
// <line opacity="0.2" stroke="#000000" stroke-width="1" x1="40" y1="78" x2="800" y2="78"/>
// <line opacity="0.2" stroke="#000000" stroke-width="1" x1="40" y1="25" x2="800" y2="25"/>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="39,26 39,560 "/>
// <text x="30" y="505" dy="0.5ex" text-anchor="end" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// -0.008
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="34,505 39,505 "/>
// <text x="30" y="452" dy="0.5ex" text-anchor="end" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// -0.006
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="34,452 39,452 "/>
// <text x="30" y="398" dy="0.5ex" text-anchor="end" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// -0.004
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="34,398 39,398 "/>
// <text x="30" y="345" dy="0.5ex" text-anchor="end" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// -0.002
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="34,345 39,345 "/>
// <text x="30" y="292" dy="0.5ex" text-anchor="end" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// 0.0
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="34,292 39,292 "/>
// <text x="30" y="238" dy="0.5ex" text-anchor="end" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// 0.002
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="34,238 39,238 "/>
// <text x="30" y="185" dy="0.5ex" text-anchor="end" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// 0.004
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="34,185 39,185 "/>
// <text x="30" y="131" dy="0.5ex" text-anchor="end" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// 0.006
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="34,131 39,131 "/>
// <text x="30" y="78" dy="0.5ex" text-anchor="end" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// 0.008
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="34,78 39,78 "/>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="40,560 800,560 "/>
// <text x="40" y="570" dy="0.76em" text-anchor="middle" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// 0
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="40,560 40,565 "/>
// <text x="213" y="570" dy="0.76em" text-anchor="middle" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// 5000
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="213,560 213,565 "/>
// <text x="387" y="570" dy="0.76em" text-anchor="middle" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// 10000
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="387,560 387,565 "/>
// <text x="560" y="570" dy="0.76em" text-anchor="middle" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// 15000
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="560,560 560,565 "/>
// <text x="734" y="570" dy="0.76em" text-anchor="middle" font-family="sans-serif" font-size="9.67741935483871" opacity="1" fill="#000000">
// 20000
// </text>
// <polyline fill="none" opacity="1" stroke="#000000" stroke-width="1" points="734,560 734,565 "/>
// <polyline fill="none" opacity="1" stroke="#FF0000" stroke-width="1" points="40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 40,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 41,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 42,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 43,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 44,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 45,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 46,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 47,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 48,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 49,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 50,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 51,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 52,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 53,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 54,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76 55,76

// %%
//println!("{:?} {:?}", ds, fs)
